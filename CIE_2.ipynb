# %% [markdown]
# <a href="https://colab.research.google.com/github/sagaryadawad/CIE1/blob/main/CIE_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('/content/tested.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
age_mean = df['Age'].mean()
age_median = df['Age'].median()
age_mode = df['Age'].mode()[0]

fare_mean = df['Fare'].mean()
fare_median = df['Fare'].median()
fare_mode = df['Fare'].mode()[0]

print("Central Tendency for Age:")
print(f"Mean: {age_mean:}")
print(f"Median: {age_median:}")
print(f"Mode: {age_mode:}")

print("\nCentral Tendency for Fare:")
print(f"Mean: {fare_mean:}")
print(f"Median: {fare_median:}")
print(f"Mode: {fare_mode:}")
# Out:
# Central Tendency for Age:
# Mean: 30.272590361445783
# Median: 27.0
# Mode: 21.0
#
# Central Tendency for Fare:
# Mean: 35.627188489208635
# Median: 14.4542
# Mode: 7.75

# %%
data['Survived'] = data['Survived'].replace({1: 'survived', 0: 'not survived'})
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.countplot(x='Survived', hue='Pclass', data=df, palette='viridis')
plt.title('Count of Survival and Pclass')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.show()

# %%
null_values = df.isnull().sum()
print("Null values in each column:")
print(null_values)
data['Age'].fillna(data['Age'].mean(),inplace=True)
data['Fare'].fillna(data['Fare'].mean(), inplace=True)
print("\nNull values after filling:")
print(df.isnull().sum())
# Out:
# Null values in each column:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# dtype: int64
#
# Null values after filling:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

plt.figure(figsize=(14, 6))
plt.title("Box plot for outiers")
threshol = 3
zsore = stats.zscore(data['Fare'])
zsore_outiers = data[np.abs(zsore) > threshol]
print("Outliers:")
print(zsore_outiers)
plt.show()
# Out:
# Outliers:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []
